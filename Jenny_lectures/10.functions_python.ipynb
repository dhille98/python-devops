# %% [markdown]
# ### 🔧 What is a Function in Python?
#
# A **function** in Python is a **reusable block of code** that performs a specific task. You define it once, and then you can call (use) it as many times as needed.
#
# ---
#
# ### ✅ Why Use Functions?
#
# - To avoid repeating code (DRY principle – Don’t Repeat Yourself)
# - To make your code modular and organized
# - To improve readability and maintainability
#
# ---
#
# ### 🧱 **Function Syntax:**
#
# ```python
# def function_name(parameters):
#     # code block
#     return result
# ```
#
# ---
#
# ### 📌 **Example – A Simple Function:**
#
# ```python
# def greet(name):
#     print(f"Hello, {name}!")
#
# greet("Alice")
# greet("Bob")
# ```
#
# 🖨️ Output:
# ```
# Hello, Alice!
# Hello, Bob!
# ```
#
# ---
#
# ### 🔁 **Function with Return Value:**
#
# ```python
# def add(a, b):
#     return a + b
#
# result = add(5, 3)
# print("Sum is:", result)
# ```
#
# 🖨️ Output:
# ```
# Sum is: 8
# ```
#
# ---
#
# ### ✨ Types of Functions:
#
# 1. **Built-in functions** – like `print()`, `len()`, `max()`, etc.
# 2. **User-defined functions** – like the ones you create using `def`
# 3. **Lambda functions** – small anonymous functions
#
# ---
#
# ## Functions in Python
# ```
# def function_name(parameters):
#     function body
#     return expression
#
# # call the function
# function_name()
# ```
# * function are two types
#       * built-in function
#       * user-defined
